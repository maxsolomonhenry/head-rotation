# %%
# %load_ext autoreload
# %autoreload 2

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

from analysis import load_data
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
df = load_data("data")

# %%
df[df['trueDirection'] == df['perceivedDirection']]['whichCondition'].hist()
plt.show()

df.groupby('whichCondition')['perceivedRealism'].hist()
plt.show()

# %%
# Out:
# [0, 1, 3]
